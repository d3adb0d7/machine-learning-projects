# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as splt
import seaborn

# %%
data_set = pd.read_csv('data/cardio_train.csv',sep=';')

# %%
data_set
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
data_set['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
seaborn.countplot(data_set['cardio'])
# Out:
# C:\Users\nafis\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cardio', ylabel='count'>

# %%
data_set.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
data_set.isnull().any()
# Out:
# id             False
# age            False
# gender         False
# height         False
# weight         False
# ap_hi          False
# ap_lo          False
# cholesterol    False
# gluc           False
# smoke          False
# alco           False
# active         False
# cardio         False
# dtype: bool

# %%
seaborn.countplot(x='gender',hue='cardio',data=data_set,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
data_set['age_year']=(data_set['age']/365).round()

# %%
data_set['age_year']
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# 69999    56.0
# Name: age_year, Length: 70000, dtype: float64

# %%
seaborn.countplot(x='age_year',hue='cardio',data=data_set,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <AxesSubplot:xlabel='age_year', ylabel='count'>

# %%
data_set.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
data_set.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %%
data_set = data_set.drop(['age_year'],axis=1)

# %%
data_set
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
x=data_set.iloc[:,:-1]

# %%
x
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# ...

# %%
y=data_set.iloc[:,12]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest , f_classif

# %%
top_features = SelectKBest(score_func=f_classif)

# %%
top_features.fit(x,y)
# Out:
# SelectKBest()

# %%
score=pd.DataFrame(top_features.scores_,columns = ['score value'])

# %%
score
# Out:
#     score value
# 0      1.010461
# 1   4209.007957
# 2      4.603641
# 3      8.197397
# 4   2388.777887
# 5    208.339524
# 6    303.629011
# 7   3599.361137
# 8    562.772977
# 9     16.790541
# 10     3.761355
# 11    89.091494

# %%
name = pd.DataFrame(x.columns)

# %%
top_sorted_feature = pd.concat([name,score],axis=1)

# %%
top_sorted_feature.nlargest(8,'score value')
# Out:
#               0  score value
# 1           age  4209.007957
# 7   cholesterol  3599.361137
# 4        weight  2388.777887
# 8          gluc   562.772977
# 6         ap_lo   303.629011
# 5         ap_hi   208.339524
# 11       active    89.091494
# 9         smoke    16.790541

# %%
from sklearn.model_selection import train_test_split

# %%
new_data_set = pd.read_csv('data/cardio_train.csv',sep=';')

# %%
new_data_set
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
new_data_set = new_data_set.drop(['id','alco','height','gender'],axis=1)

# %%
new_data_set
# Out:
#          age  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  active  cardio
# 0      18393    62.0    110     80            1     1      0       1       0
# 1      20228    85.0    140     90            3     1      0       1       1
# 2      18857    64.0    130     70            3     1      0       0       1
# 3      17623    82.0    150    100            1     1      0       1       1
# 4      17474    56.0    100     60            1     1      0       0       0
# ...      ...     ...    ...    ...          ...   ...    ...     ...     ...
# 69995  19240    76.0    120     80            1     1      1       1       0
# 69996  22601   126.0    140     90            2     2      0       1       1
# 69997  19066   105.0    180     90            3     1      0       0       1
# 69998  22431    72.0    135     80            1     2      0       0       1
# 69999  20540    72.0    120     80            2     1      0       1       0
#
# [70000 rows x 9 columns]

# %%
x=new_data_set.iloc[:,:-1]

# %%
x
# Out:
#          age  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  active
# 0      18393    62.0    110     80            1     1      0       1
# 1      20228    85.0    140     90            3     1      0       1
# 2      18857    64.0    130     70            3     1      0       0
# 3      17623    82.0    150    100            1     1      0       1
# 4      17474    56.0    100     60            1     1      0       0
# ...      ...     ...    ...    ...          ...   ...    ...     ...
# 69995  19240    76.0    120     80            1     1      1       1
# 69996  22601   126.0    140     90            2     2      0       1
# 69997  19066   105.0    180     90            3     1      0       0
# 69998  22431    72.0    135     80            1     2      0       0
# 69999  20540    72.0    120     80            2     1      0       1
#
# [70000 rows x 8 columns]

# %%
y=new_data_set.iloc[:,8]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.30,random_state=1)

# %%
xtrain
# Out:
#          age  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  active
# 23561  16136    71.0    100     80            1     1      1       1
# 34858  14615    69.0    140     80            2     1      0       1
# 54953  20507    65.0    120     80            1     1      0       1
# 59230  16720    53.0    100     60            1     1      0       1
# 1730   21050    71.0    140     90            1     1      0       1
# ...      ...     ...    ...    ...          ...   ...    ...     ...
# 49100  21289    78.0    120     80            1     1      0       1
# 20609  19116    68.0    120     80            1     1      0       0
# 21440  18049    82.0    120     80            1     1      0       1
# 50057  21957    77.0    120     80            1     1      0       0
# 5192   20671    65.0    160     90            2     2      0       1
#
# [49000 rows x 8 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rclf = RandomForestClassifier()

# %%
rclf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rclf.score(xtest,ytest)
# Out:
# 0.6898571428571428

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dclf = DecisionTreeClassifier()

# %%
dclf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dclf.score(xtest,ytest)
# Out:
# 0.6328571428571429

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nclf = GaussianNB()

# %%
nclf.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
nclf.score(xtest,ytest)
# Out:
# 0.5812857142857143

# %%
from sklearn.svm import SVC

# %%
sclf = SVC()

# %%
sclf.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
sclf.score(xtest,ytest)
# Out:
# 0.6046666666666667
